# %% [markdown]
# # Tayler Stegman
# ## Week 15 - 12/28/23
# ### Python Data Visualization - Making informative visualizations (using plots)

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

#These are the plotting libraries
import matplotlib as mpl
import matplotlib.pyplot as plt

#Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
data = randn(10)
data
# Out:
# array([-0.15489466, -0.48251898,  0.46801571, -1.45012977, -0.23297098,
#        -0.00915795, -0.80333883,  1.6261075 ,  0.2681955 ,  1.17913212])

# %%
plt.plot(data)

# %%
data = np.array([1, 2, 3, 4, 2, 3, 3, 4, 5,6, 7, 8, 1, 1, 1, 1, 1])*100
data
# Out:
# array([100, 200, 300, 400, 200, 300, 300, 400, 500, 600, 700, 800, 100,
#        100, 100, 100, 100])

# %%
plt.plot(data)

# %%
data = randn(20)
df = pd.DataFrame(data)
df
# Out:
#            0
# 0   0.634203
# 1  -1.743483
# 2  -0.699237
# 3  -0.660704
# 4  -1.690962
# 5  -0.388194
# 6  -0.207703
# 7   0.556403
# 8   0.121553
# 9  -0.740343
# 10  0.719985
# 11 -0.338862
# 12 -0.206337
# 13 -0.126241
# 14 -0.357891
# 15 -1.116234
# 16  1.214874
# 17  2.187790
# 18 -0.156671
# 19  1.817527

# %%
plt.plot(df)

# %%
dataset1 = randn(100)
dataset1
# Out:
# array([ 1.10389389,  0.07624466,  0.19866285, -0.63970455,  0.91478718,
#         0.46590686, -0.65007509, -0.2823624 , -0.96102936,  0.02867679,
#         0.38203983, -2.02862044,  0.98919246, -0.30568845, -0.28372995,
#        -0.3248008 ,  0.47053357, -0.71133995, -0.30654516,  0.84366359,
#        -1.22810336,  1.07612795, -0.32456899, -0.78020508, -0.91285515,
#        -0.19124388, -2.51659151, -0.10540696,  2.72228789, -0.92635226,
#         0.99873021,  0.87988268, -0.91282292, -0.61487533,  0.33651013,
#        -0.41398885,  0.85003443, -0.24263534, -0.5553624 , -1.26519324,
#        -0.51457836, -1.69481782,  0.18282462,  2.13462963,  1.17331101,
#        -0.35424111, -0.84841418, -0.10865174, -1.11857849,  0.16254773,
#        -0.40799873,  0.74956114, -1.10678594, -1.22181491,  0.57906874,
#        -0.21435763,  0.53640858,  0.51792326, -0.61179129,  0.62954725,
#         2.61840089, -0.04647337, -1.77710289,  0.15090146, -0.74735554,
# ...

# %%
plt.hist(dataset1)
# Out:
# (array([ 4.,  5., 10., 21., 25., 19., 10.,  1.,  1.,  4.]),
#  array([-2.51659151, -1.99068732, -1.46478312, -0.93887893, -0.41297474,
#          0.11292946,  0.63883365,  1.16473784,  1.69064204,  2.21654623,
#          2.74245042]),
#  <a list of 10 Patch objects>)

# %%
# you can change color and it takes various formats in this example hexadecimal
dataset2 = randn(100)
plt.hist(dataset2, color="#978EFF")
# Out:
# (array([ 3.,  6.,  8., 25., 23., 17., 10.,  4.,  2.,  2.]),
#  array([-2.64733444, -2.06510887, -1.48288331, -0.90065775, -0.31843219,
#          0.26379338,  0.84601894,  1.4282445 ,  2.01047007,  2.59269563,
#          3.17492119]),
#  <a list of 10 Patch objects>)

# %%
# you can change color and it takes various formats in this example string
dataset2 = randn(100)
plt.hist(dataset2, color="indianred")
# Out:
# (array([ 2.,  4.,  9., 13., 24., 18., 15.,  8.,  5.,  2.]),
#  array([-2.32992346, -1.86924757, -1.40857168, -0.94789578, -0.48721989,
#         -0.026544  ,  0.4341319 ,  0.89480779,  1.35548368,  1.81615957,
#          2.27683547]),
#  <a list of 10 Patch objects>)

# %%
#alpha changes the transparency
plt.hist(dataset1, color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2, alpha=0.5, bins=20)
# Out:
# (array([ 1.,  1.,  1.,  3.,  3.,  6.,  7.,  6., 16.,  8., 10.,  8., 10.,
#          5.,  6.,  2.,  1.,  4.,  0.,  2.]),
#  array([-2.32992346, -2.09958551, -1.86924757, -1.63890962, -1.40857168,
#         -1.17823373, -0.94789578, -0.71755784, -0.48721989, -0.25688194,
#         -0.026544  ,  0.20379395,  0.4341319 ,  0.66446984,  0.89480779,
#          1.12514573,  1.35548368,  1.58582163,  1.81615957,  2.04649752,
#          2.27683547]),
#  <a list of 20 Patch objects>)

# %%
#Figures and subplots
fig = plt.figure()

# %%
fig = plt.figure(figsize = (2,4), dpi=1000)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1) #add_subplot(nrows, ncols, index, **kwargs)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(2,2,4)
plt.plot(randn(5))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot(np.arange(5))

ax2 = fig.add_subplot(2, 2, 2)
plt.plot([1,-0.5,0,1.23])

ax3 = fig.add_subplot(2,2,3)
plt.plot([1.5, 3.5, -2, 1.6])

ax4 = fig.add_subplot(2,2,4)
plt.plot(randn(5))

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,0.4,0.4)) #add_axes ([left, bottom, width, height])

# %%
# I believe he describes the arguments wrong. I think they change the position on the screen the graphs don't change in size
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,0.4,0.4)) #add_axes ([left, bottom, width, height])
ax1 = fig1.add_axes((0.25,0.25,0.3,0.3))

# %%
dataset = randn(50).cumsum()
dataset
# Out:
# array([-6.53683354e-01,  8.95173723e-01,  1.21287071e-01,  4.60857662e-01,
#         5.75316352e-02, -4.93593489e-01, -1.61622304e+00, -2.20629884e+00,
#        -2.68693496e+00, -2.01202012e+00, -2.15648015e+00, -2.88927540e+00,
#        -2.35002603e+00, -2.48617139e+00, -1.86024651e+00, -1.52877945e+00,
#        -2.57770600e+00, -1.91380592e+00, -1.09372312e+00,  1.22266434e-01,
#         1.08318390e+00, -6.17477624e-01, -8.91862137e-01, -3.56099183e-01,
#         1.10174174e+00,  1.01403129e+00, -7.03358685e-01,  9.00270252e-01,
#        -3.69499750e-01,  1.83341834e-02, -3.54161007e-01,  1.49369632e-03,
#        -2.35044079e-01, -1.31078748e+00, -1.38628143e+00, -1.43579783e+00,
#        -1.48323644e+00, -2.83862479e+00, -2.54286922e+00, -3.57786619e+00,
#        -3.41407397e+00, -3.73198542e+00, -3.93859689e+00, -2.38099102e+00,
#        -3.54778022e+00, -2.31141503e+00, -2.86303943e+00, -4.33238846e+00,
#        -4.12920510e+00, -4.03226082e+00])

# %%
fig3 = plt.figure()
ax1 = fig3.add_subplot(2,1,1)
ax2 = fig3.add_subplot(2,1,2)

ax1.plot(dataset, 'k-')
ax1.plot(dataset, 'k--')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.hist(randn(100), bins=20, color='k', alpha=0.25)

ax2 = fig.add_subplot(2,2,2)
ax2.scatter(np.arange(30), randn(30),randn(30).cumsum())

ax3 = fig.add_subplot(2,2,3)
ax3.plot(dataset, 'k---')
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\matplotlib\collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-a2f9110d6d74> in <module>
#       7
#       8 ax3 = fig.add_subplot(2,2,3)
# ----> 9 ax3.plot(dataset, 'k---')
#
# c:\Miniconda\envs\py37_default\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# c:\Miniconda\envs\py37_default\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
# ...

# %%
#plot with pandas
df1 = pd.DataFrame(randn(30).cumsum())
df1
# Out:
#            0
# 0  -0.412991
# 1  -0.365915
# 2   1.500138
# 3   0.942821
# 4   1.576407
# 5   2.064052
# 6   1.862364
# 7   0.012230
# 8   0.940016
# 9   0.479805
# 10 -0.292050
# 11 -1.266812
# 12  0.304416
# 13  0.203893
# 14 -0.953978
# 15 -1.425183
# 16 -0.760310
# 17 -1.113191
# 18  0.101994
# 19 -0.191082
# 20 -0.202436
# 21  0.445231
# 22  2.243887
# 23  2.840837
# 24  3.633880
# 25  3.879455
# 26  3.309066
# 27  4.324942
# 28  4.396577
# 29  5.018426

# %%
#plot with pandas
df1.plot()

# %%
#plot with matplot
plt.plot(df1)

# %%
plt.plot(df1, drawstyle='steps-post')

# %%
plt.plot(data, 'k--')
plt.plot(data, 'k--', drawstyle='steps-post')

# %%
data = randn(50).cumsum()
data
# Out:
# array([  1.15409188,  -0.53977667,  -0.09934164,  -0.60946126,
#         -1.0470577 ,  -1.15982323,  -1.84059507,  -1.15181685,
#         -0.68657197,   0.66148224,   0.66674442,  -0.26257467,
#         -0.91088858,  -1.35803963,  -1.32314904,  -1.47181522,
#         -1.6478752 ,  -1.41481221,  -0.79560634,  -2.50033298,
#         -0.14134346,  -0.09170996,  -0.50548351,  -2.09469081,
#         -1.95514505,  -2.68229383,  -3.55140576,  -3.8759587 ,
#         -5.15075812,  -6.59023814,  -7.22241201,  -6.90560902,
#         -9.17742733, -10.11558767,  -8.2833096 ,  -8.78534871,
#        -10.01068843, -10.91245923,  -8.88180597,  -8.17660596,
#         -8.0264044 ,  -8.92703639, -10.55989007,  -9.35714329,
#        -10.21477057,  -9.58840567,  -9.10030363, -10.29689911,
#        -12.25127169, -13.68677447])

# %%
# how to use labels
plt.plot(data, 'k--', label='dashed-line')
plt.plot(data, 'k-', drawstyle='steps-post',label='steps-post')
plt.legend(loc='best')
#Place a legend on the ["upper left", 'lower left', 'center right']

# %%
d = {'col1': randn(30).cumsum(), 'col2':randn(30).cumsum()}
df2 = pd.DataFrame(d)
df2
# Out:
#         col1      col2
# 0  -1.860769  0.032131
# 1  -2.553280  1.256509
# 2  -3.100960  2.348419
# 3  -3.621548  0.439097
# 4  -3.424928  1.530011
# 5  -3.814356  0.278759
# 6  -2.848203 -1.203791
# 7  -2.948030 -1.836511
# 8  -4.351497 -0.984073
# 9  -4.482971  1.037091
# 10 -6.018768  1.190548
# 11 -6.234343  3.145474
# 12 -6.445655  2.900676
# 13 -5.643949  3.726650
# 14 -5.661381  4.823164
# 15 -6.803212  5.165886
# 16 -7.003408  4.617597
# 17 -6.356504  3.964765
# 18 -6.362126  3.869339
# 19 -5.867853  4.095161
# 20 -6.058038  1.642497
# 21 -6.573093  2.176747
# 22 -6.389638  3.979536
# 23 -7.513300  4.619611
# 24 -8.153007  5.380498
# 25 -7.251780  6.059868
# 26 -6.530740  5.512651
# 27 -7.310413  4.149643
# 28 -7.751597  3.388000
# 29 -7.681908  3.559273

# %%
plt.plot(df2['col1'], 'k', label='col1')
plt.plot(df2['col2'], 'ko--', label='col2')
plt.legend(loc='best')

# %%
df2['col1'].plot.bar()

# %%
#Ticks, labels, and legends
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum())

# %%
ax.set_xticks([0, 250, 500, 750, 1000])

ax.set_xticklabels(['one', 'two','three', 'four', 'five'], rotation=30, fontsize='small')

ax.set_title('My First Mathplotlip Plot with Ticks')

ax.set_xlabel('Stages')
ax.set_ylabel('Values')

fig

# %%
#Use dictionary for title, xLabel, and yLabel
props ={'title': 'YOOOOOOOOOOOOOOOOOO',
       'xlabel': 'Stages',
       'ylabel': 'Values'}

ax.set(**props)
fig

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(), 'k--', label="One")
ax.plot(randn(1000).cumsum(), 'k--', label="Two")
ax.plot(randn(1000).cumsum(), 'k--', label="Three")

ax.legend(loc='best')

# %%
#Saving a figure in a image file
fig.savefig('Png1')

# %%
print(np.random.randn(100))
# Out:
# [-0.94540328  0.80131119  0.70425734  0.12713135 -1.18078861 -1.96503537
#  -0.48887673  1.15445435  0.36164603 -0.79203748 -0.59867165  0.48806895
#  -0.07209686  0.55671881 -1.93808308 -0.14443895 -0.31657078  2.72923073
#  -0.12212996 -1.42616103  0.26367892 -0.72633939  0.4446625   0.41642997
#  -0.08169117 -0.2133926  -0.9604932  -0.4899745  -0.46988683  1.03553164
#  -0.52041865  0.89398735 -0.4247352   0.95513949 -0.84391894  0.76830308
#  -0.79184382  1.53517517  0.65026261 -0.92463114  1.59243414 -0.01426662
#   0.83732235  0.98791705  0.67682709 -1.40200386 -0.81013847  1.0799729
#   0.03843792 -0.91698489  0.50473738 -0.74348155  0.74941135 -1.14556709
#   0.5879475   0.54745116 -0.31099376  1.42328781 -0.44731829 -0.32706977
#   0.27407422  0.5381125   0.19001839  0.69563885 -0.00961582 -0.53259789
#   0.96716559 -0.48420417 -0.72214514 -0.58509817  0.93316311  0.00570056
#  -0.16955479 -0.41840247 -1.00674911 -1.77666922 -1.05447802  0.20163311
# ...
